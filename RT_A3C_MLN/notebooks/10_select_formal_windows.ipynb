# %% [markdown]
# # 10_select_formal_windows
#
# 目标：从 `windows_mixed.csv` 中按 attack ratio 分层抽取足够多的 mixed windows，生成正式实验计划表。

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = (Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd())
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

from src.analysis.window_selection import build_large_scale_plan

# %%
selected = build_large_scale_plan(
    project_root=ROOT,
    low_per_bin= 8,
    mid_per_bin= 8,
    high_per_bin = 8,
    out_name='formal_mixed_windows_plan.csv',
)

print('selected windows =', len(selected))
display(selected)

# %%
print(selected.groupby('attack_bin')['window_id'].count())
print(selected[['attack_ratio']].describe())
