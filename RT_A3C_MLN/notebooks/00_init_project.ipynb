# %%
from pathlib import Path

root = (Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd())   # 改成你的实际路径

dirs = [
    "data/raw",
    "data/processed",
    "data/stream",
    "notebooks",
    "src/data",
    "src/mln",
    "src/rl",
    "src/utils",
    "outputs/logs",
    "outputs/models",
    "outputs/figures",
]

for d in dirs:
    (root / d).mkdir(parents=True, exist_ok=True)

print("项目目录创建完成：", root)
